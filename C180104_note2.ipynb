# %%
import numpy as np
#画像
from IPython.display import Image, display

# %%
Image('./multilayer_nn_1.jpg')

# %%
i_count=4
h_count=3
o_count=2

np.random.seed(45)

X=np.random.randn(4)
X
# Out:
# array([ 0.02637477,  0.2603217 , -0.39514554, -0.20430091])

# %%
w_i_to_h = np.random.normal(0,scale=0.1,size=(i_count,h_count))
w_i_to_h
# Out:
# array([[-0.12716327, -0.25968786,  0.02896809],
#        [-0.08733046,  0.03940727,  0.09351055],
#        [-0.00156847,  0.0259596 , -0.14733142],
#        [ 0.08019266, -0.17507524, -0.04950519]])

# %%
w_h_to_o = np.random.normal(0,scale=0.1,size=(h_count,o_count))
w_h_to_o
# Out:
# array([[-0.10086008,  0.00252442],
#        [-0.01215069, -0.15468732],
#        [-0.0606944 , -0.13938127]])
